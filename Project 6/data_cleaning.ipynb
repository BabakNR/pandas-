# %% [markdown]
# # Data Cleaning - Medical Appointments Dataset

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Load dataset
df = pd.read_csv("C:\\Users\\Ali\\Desktop\\data cleaning\\Medical Appointment.csv")

# %%
# Initial exploration
df.shape
# Out:
# (110527, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 110527 entries, 0 to 110526
# Data columns (total 14 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   PatientId       110527 non-null  float64
#  1   AppointmentID   110527 non-null  int64
#  2   Gender          110527 non-null  object
#  3   ScheduledDay    110527 non-null  object
#  4   AppointmentDay  110527 non-null  object
#  5   Age             110527 non-null  int64
#  6   Neighbourhood   110527 non-null  object
#  7   Scholarship     110527 non-null  int64
#  8   Hipertension    110527 non-null  int64
#  9   Diabetes        110527 non-null  int64
#  10  Alcoholism      110527 non-null  int64
#  11  Handcap         110527 non-null  int64
#  12  SMS_received    110527 non-null  int64
#  13  No-show         110527 non-null  object
# dtypes: float64(1), int64(8), object(5)
# memory usage: 11.8+ MB

# %%
df.head()
# Out:
#       PatientId  AppointmentID Gender          ScheduledDay  \
# 0  2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1  5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2  4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3  8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4  8.841186e+12        5642494      F  2016-04-29T16:07:23Z
#
#          AppointmentDay  Age      Neighbourhood  Scholarship  Hipertension  \
# 0  2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0             1
# 1  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             0
# 2  2016-04-29T00:00:00Z   62      MATA DA PRAIA            0             0
# 3  2016-04-29T00:00:00Z    8  PONTAL DE CAMBURI            0             0
# 4  2016-04-29T00:00:00Z   56    JARDIM DA PENHA            0             1
#
#    Diabetes  Alcoholism  Handcap  SMS_received No-show
# 0         0           0        0             0      No
# ...

# %%
df.isnull().sum()
# Out:
# PatientId         0
# AppointmentID     0
# Gender            0
# ScheduledDay      0
# AppointmentDay    0
# Age               0
# Neighbourhood     0
# Scholarship       0
# Hipertension      0
# Diabetes          0
# Alcoholism        0
# Handcap           0
# SMS_received      0
# No-show           0
# dtype: int64

# %%
# Rename columns
df.columns = [col.strip().lower().replace('-', '_') for col in df.columns]

# %%
df
# Out:
#            patientid  appointmentid gender          scheduledday  \
# 0       2.987250e+13        5642903      F  2016-04-29T18:38:08Z
# 1       5.589978e+14        5642503      M  2016-04-29T16:08:27Z
# 2       4.262962e+12        5642549      F  2016-04-29T16:19:04Z
# 3       8.679512e+11        5642828      F  2016-04-29T17:29:31Z
# 4       8.841186e+12        5642494      F  2016-04-29T16:07:23Z
# ...              ...            ...    ...                   ...
# 110522  2.572134e+12        5651768      F  2016-05-03T09:15:35Z
# 110523  3.596266e+12        5650093      F  2016-05-03T07:27:33Z
# 110524  1.557663e+13        5630692      F  2016-04-27T16:03:52Z
# 110525  9.213493e+13        5630323      F  2016-04-27T15:09:23Z
# 110526  3.775115e+14        5629448      F  2016-04-27T13:30:56Z
#
#               appointmentday  age      neighbourhood  scholarship  \
# 0       2016-04-29T00:00:00Z   62    JARDIM DA PENHA            0
# ...

# %%
# Check for duplicate rows
print("Number of duplicate rows:", df.duplicated().sum())
# Out:
# Number of duplicate rows: 0

# %%
# Drop duplicates
df.drop_duplicates(inplace=True)

# %%
# Remove negative ages
df = df[df.age >= 0]

# %%
# Convert dates
df['scheduledday'] = pd.to_datetime(df['scheduledday'])
df['appointmentday'] = pd.to_datetime(df['appointmentday'])
df['days_between'] = (df['appointmentday'] - df['scheduledday']).dt.days
# Out:
# C:\Users\Ali\AppData\Local\Temp\ipykernel_8400\2528665960.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['scheduledday'] = pd.to_datetime(df['scheduledday'])
# C:\Users\Ali\AppData\Local\Temp\ipykernel_8400\2528665960.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['appointmentday'] = pd.to_datetime(df['appointmentday'])
# C:\Users\Ali\AppData\Local\Temp\ipykernel_8400\2528665960.py:4: SettingWithCopyWarning:
# ...

# %%
df = df[df['days_between'] >= 0]

# %%
df.head()
# Out:
#        patientid  appointmentid gender              scheduledday  \
# 5   9.598513e+13        5626772      F 2016-04-27 08:36:51+00:00
# 6   7.336882e+14        5630279      F 2016-04-27 15:05:12+00:00
# 7   3.449833e+12        5630575      F 2016-04-27 15:39:58+00:00
# 9   7.812456e+13        5629123      F 2016-04-27 12:48:25+00:00
# 10  7.345362e+14        5630213      F 2016-04-27 14:58:11+00:00
#
#               appointmentday  age   neighbourhood  scholarship  hipertension  \
# 5  2016-04-29 00:00:00+00:00   76       REPÚBLICA            0             1
# 6  2016-04-29 00:00:00+00:00   23      GOIABEIRAS            0             0
# 7  2016-04-29 00:00:00+00:00   39      GOIABEIRAS            0             0
# 9  2016-04-29 00:00:00+00:00   19       CONQUISTA            0             0
# 10 2016-04-29 00:00:00+00:00   30  NOVA PALESTINA            0             0
#
#     diabetes  alcoholism  handcap  sms_received no_show  days_between
# ...

# %%
# Convert categorical columns
df['no_show'] = df['no_show'].map({'No': 0, 'Yes': 1})

# %%
df.head()
# Out:
#        patientid  appointmentid gender              scheduledday  \
# 5   9.598513e+13        5626772      F 2016-04-27 08:36:51+00:00
# 6   7.336882e+14        5630279      F 2016-04-27 15:05:12+00:00
# 7   3.449833e+12        5630575      F 2016-04-27 15:39:58+00:00
# 9   7.812456e+13        5629123      F 2016-04-27 12:48:25+00:00
# 10  7.345362e+14        5630213      F 2016-04-27 14:58:11+00:00
#
#               appointmentday  age   neighbourhood  scholarship  hipertension  \
# 5  2016-04-29 00:00:00+00:00   76       REPÚBLICA            0             1
# 6  2016-04-29 00:00:00+00:00   23      GOIABEIRAS            0             0
# 7  2016-04-29 00:00:00+00:00   39      GOIABEIRAS            0             0
# 9  2016-04-29 00:00:00+00:00   19       CONQUISTA            0             0
# 10 2016-04-29 00:00:00+00:00   30  NOVA PALESTINA            0             0
#
#     diabetes  alcoholism  handcap  sms_received  no_show  days_between
# ...

# %%
df['gender'] = df['gender'].str.strip().str.upper()

# %%
df
# Out:
#            patientid  appointmentid gender              scheduledday  \
# 5       9.598513e+13        5626772      F 2016-04-27 08:36:51+00:00
# 6       7.336882e+14        5630279      F 2016-04-27 15:05:12+00:00
# 7       3.449833e+12        5630575      F 2016-04-27 15:39:58+00:00
# 9       7.812456e+13        5629123      F 2016-04-27 12:48:25+00:00
# 10      7.345362e+14        5630213      F 2016-04-27 14:58:11+00:00
# ...              ...            ...    ...                       ...
# 110522  2.572134e+12        5651768      F 2016-05-03 09:15:35+00:00
# 110523  3.596266e+12        5650093      F 2016-05-03 07:27:33+00:00
# 110524  1.557663e+13        5630692      F 2016-04-27 16:03:52+00:00
# 110525  9.213493e+13        5630323      F 2016-04-27 15:09:23+00:00
# 110526  3.775115e+14        5629448      F 2016-04-27 13:30:56+00:00
#
#                   appointmentday  age   neighbourhood  scholarship  \
# 5      2016-04-29 00:00:00+00:00   76       REPÚBLICA            0
# ...

# %%
# Step 1: Visualize boxplots before removing outliers
for col in ['age', 'days_between']:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col} before removing outliers')
    plt.xlabel(col)
    plt.show()
# Out:
# D:\Users\Ali\miniconda3\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# D:\Users\Ali\miniconda3\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
# Step 2: Define IQR-based outlier detection function
def detect_outliers_iqr(data, column):
    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outliers = data[(data[column] < lower) | (data[column] > upper)]
    print(f"{column} - Number of outliers: {len(outliers)}")
    return outliers.index

# %%
# Step 3: Detect and remove outliers from numeric columns
for col in ['age', 'days_between']:
    outlier_indices = detect_outliers_iqr(df, col)
    df.drop(outlier_indices, inplace=True)
# Out:
# age - Number of outliers: 0
# days_between - Number of outliers: 442

# %%
# Optional: Visualize cleaned data after removing outliers
for col in ['age', 'days_between']:
    plt.figure(figsize=(8, 4))
    sns.boxplot(x=df[col])
    plt.title(f'Boxplot of {col} after removing outliers')
    plt.xlabel(col)
    plt.show()
# Out:
# D:\Users\Ali\miniconda3\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)
# D:\Users\Ali\miniconda3\Lib\site-packages\seaborn\categorical.py:632: FutureWarning: SeriesGroupBy.grouper is deprecated and will be removed in a future version of pandas.
#   positions = grouped.grouper.result_index.to_numpy(dtype=float)

# %%
# Final check
df.shape
# Out:
# (68203, 15)

# %%
df.describe()
# Out:
#           patientid  appointmentid           age   scholarship  hipertension  \
# count  6.820300e+04   6.820300e+04  68203.000000  68203.000000  68203.000000
# mean   1.449445e+14   5.665187e+06     38.134862      0.095230      0.209346
# std    2.532364e+14   5.970642e+04     22.822972      0.293535      0.406845
# min    3.921784e+04   5.462955e+06      0.000000      0.000000      0.000000
# 25%    3.973611e+12   5.625848e+06     19.000000      0.000000      0.000000
# 50%    2.984234e+13   5.665614e+06     38.000000      0.000000      0.000000
# 75%    9.348643e+13   5.709886e+06     56.000000      0.000000      0.000000
# max    9.999320e+14   5.784985e+06    102.000000      1.000000      1.000000
#
#            diabetes    alcoholism       handcap  sms_received       no_show  \
# count  68203.000000  68203.000000  68203.000000  68203.000000  68203.000000
# mean       0.075173      0.026113      0.020131      0.485287      0.284137
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 68203 entries, 5 to 110526
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   patientid       68203 non-null  float64
#  1   appointmentid   68203 non-null  int64
#  2   gender          68203 non-null  object
#  3   scheduledday    68203 non-null  datetime64[ns, UTC]
#  4   appointmentday  68203 non-null  datetime64[ns, UTC]
#  5   age             68203 non-null  int64
#  6   neighbourhood   68203 non-null  object
#  7   scholarship     68203 non-null  int64
#  8   hipertension    68203 non-null  int64
#  9   diabetes        68203 non-null  int64
#  10  alcoholism      68203 non-null  int64
#  11  handcap         68203 non-null  int64
#  12  sms_received    68203 non-null  int64
#  13  no_show         68203 non-null  int64
#  14  days_between    68203 non-null  int64
# dtypes: datetime64[ns, UTC](2), float64(1), int64(10), object(2)
# memory usage: 8.3+ MB

# %%
# Save cleaned dataset
df.to_csv("C:\\Users\\Ali\\Desktop\\appointments_cleaned.csv", index=False)
